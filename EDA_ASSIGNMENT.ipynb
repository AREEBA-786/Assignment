# %% [markdown]
# <a href="https://colab.research.google.com/github/AREEBA-786/Assignment/blob/main/EDA_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA

# %% [markdown]
# Hi everyone, This is your first assignment for week 1...
# So in this assignment you have to perform EDA on the below dataset.
# The problem statements are given below.
# Just write a code for them...

# %%
# !wget https://www.kaggle.com/datasets/aestheteaman01/zomato-restaurants-in-delhi-ncr
# Out:
# --2023-09-17 05:54:37--  https://www.kaggle.com/datasets/aestheteaman01/zomato-restaurants-in-delhi-ncr
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘zomato-restaurants-in-delhi-ncr’
#
# zomato-restaurants-     [ <=>                ]  15.99K  --.-KB/s    in 0.02s
#
# 2023-09-17 05:54:37 (977 KB/s) - ‘zomato-restaurants-in-delhi-ncr’ saved [16372]

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("DelhiNCR Restaurants.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (1965, 15)

# %%
data.columns
# Out:
# Index(['Restaurant_Name', 'Category', 'Pricing_for_2', 'Locality',
#        'Dining_Rating', 'Dining_Review_Count', 'Delivery_Rating',
#        'Delivery_Rating_Count', 'Website', 'Address', 'Phone_No', 'Latitude',
#        'Longitude', 'Known_For2', 'Known_For22'],
#       dtype='object')

# %% [markdown]
# Q1.Are there any null values in the dataset?if yes then fill them..

# %%
data
# Out:
#              Restaurant_Name  \
# 0                   Rustom's
# 1                  Cafe Lota
# 2     Dum-Pukht - ITC Maurya
# 3                Burma Burma
# 4              The Big Chill
# ...                      ...
# 1960          Bablu Chic-Inn
# 1961               Kovilakam
# 1962        Krips Restaurant
# 1963                Cafe 147
# 1964                Pizzasia
#
#                                                Category  Pricing_for_2  \
# 0     Parsi, Street Food, North Indian, Desserts, Be...           2100
# 1           Cafe, South Indian, North Indian, Beverages           1200
# 2                       Mughlai, North Indian, Desserts           5000
# 3           Asian, Burmese, Bubble Tea, Desserts, Salad           1600
# 4                        Continental, American, Italian           1500
# ...                                                 ...            ...
# 1960          Mughlai, North Indian, Chinese, Fast Food            500
# ...

# %%
data.head(4)
# Out:
#           Restaurant_Name                                           Category  \
# 0                Rustom's  Parsi, Street Food, North Indian, Desserts, Be...
# 1               Cafe Lota        Cafe, South Indian, North Indian, Beverages
# 2  Dum-Pukht - ITC Maurya                    Mughlai, North Indian, Desserts
# 3             Burma Burma        Asian, Burmese, Bubble Tea, Desserts, Salad
#
#    Pricing_for_2                              Locality  Dining_Rating  \
# 0           2100                        ITO, New Delhi            4.9
# 1           1200             Pragati Maidan, New Delhi            4.9
# 2           5000   ITC Maurya, Chanakyapuri, New Delhi            4.9
# 3           1600    Cyber Hub, DLF Cyber City, Gurgaon            4.9
#
#    Dining_Review_Count  Delivery_Rating  Delivery_Rating_Count  \
# 0                 1885              4.4                   1844
# 1                 3748              3.9                     37
# ...

# %%
data.tail(4)
# Out:
#        Restaurant_Name                                           Category  \
# 1961         Kovilakam                                       South Indian
# 1962  Krips Restaurant                     North Indian, Chinese, Mughlai
# 1963          Cafe 147  Cafe, North Indian, Chinese, Kashmiri, Rolls, ...
# 1964          Pizzasia                        Pizza, Fast Food, Beverages
#
#       Pricing_for_2                                     Locality  \
# 1961            350                    Dilshad Garden, New Delhi
# 1962            900   Basant Lok Market, Vasant Vihar, New Delhi
# 1963            800                      Sainik Farms, New Delhi
# 1964            500                   Gaur City 2, Greater Noida
#
#       Dining_Rating  Dining_Review_Count  Delivery_Rating  \
# 1961            3.9                  114              NaN
# 1962            3.9                  316              3.9
# 1963            3.9                  120              3.8
# ...

# %%
data.isnull().sum()
# Out:
# Restaurant_Name            0
# Category                   0
# Pricing_for_2              0
# Locality                   0
# Dining_Rating              0
# Dining_Review_Count        0
# Delivery_Rating          402
# Delivery_Rating_Count      0
# Website                    0
# Address                    0
# Phone_No                   0
# Latitude                   0
# Longitude                  0
# Known_For2               405
# Known_For22              841
# dtype: int64

# %%
data['Known_For22'].value_counts()
# Out:
# Pretty Decor, Perfect Presentation, Tamper Proof Packaging, Worth the Money, Packing, Food Quality                     2
# Artistic Decor, The Service, Natural Ambience, Fusion Menu, Serene Ambience, Fusion Food                               1
# Excellent Place, Great Value, Nice Service, Recommended Place, Good Quality Food, Amazing Taste                        1
# Amazing Food and Experience, Delivery Instructions, Genuine Price, Faster Delivery, Worth the Price, Food Packaging    1
# Budget Food, Good for Large Groups, Packed on Weekends, Portions, Good Taste, Main Course                              1
#                                                                                                                       ..
# Classy Decor, Wonderful Service, Chinese, Server, Excellent Food, Hospitality                                          1
# Pocket Friendly, Nice Crowd, Great Ambiance, Polite Staff, Prompt Service, Worth the Money                             1
# ...

# %%
data=data.fillna(value='Known_For22')

# %%
data.isnull().sum()
# Out:
# Restaurant_Name          0
# Category                 0
# Pricing_for_2            0
# Locality                 0
# Dining_Rating            0
# Dining_Review_Count      0
# Delivery_Rating          0
# Delivery_Rating_Count    0
# Website                  0
# Address                  0
# Phone_No                 0
# Latitude                 0
# Longitude                0
# Known_For2               0
# Known_For22              0
# dtype: int64

# %%
data.head()
# Out:
#           Restaurant_Name                                           Category  \
# 0                Rustom's  Parsi, Street Food, North Indian, Desserts, Be...
# 1               Cafe Lota        Cafe, South Indian, North Indian, Beverages
# 2  Dum-Pukht - ITC Maurya                    Mughlai, North Indian, Desserts
# 3             Burma Burma        Asian, Burmese, Bubble Tea, Desserts, Salad
# 4           The Big Chill                     Continental, American, Italian
#
#    Pricing_for_2                              Locality  Dining_Rating  \
# 0           2100                        ITO, New Delhi            4.9
# 1           1200             Pragati Maidan, New Delhi            4.9
# 2           5000   ITC Maurya, Chanakyapuri, New Delhi            4.9
# 3           1600    Cyber Hub, DLF Cyber City, Gurgaon            4.9
# 4           1500                Khan Market, New Delhi            4.9
#
#    Dining_Review_Count Delivery_Rating  Delivery_Rating_Count  \
# ...

# %% [markdown]
# Q2.Which restaurant is the best one having ratings more than 4.5 for delivery

# %%
X1=data['Delivery_Rating'].value_counts()
print(X1)
# Out:
# Known_For22    402
# 3.9            304
# 4.0            264
# 4.1            253
# 4.2            177
# 3.8            140
# 4.3            135
# 3.7             99
# 3.6             60
# 3.5             50
# 4.4             26
# 3.4             20
# 3.3             11
# 4.5              8
# 3.2              6
# 3.1              5
# 3.0              3
# 2.8              1
# 2.9              1
# Name: Delivery_Rating, dtype: int64

# %%
Y1=data['Restaurant_Name'].value_counts()
print(Y1)
# Out:
# Punjabi Zaika                    4
# Champaran Meat House             3
# Kathi Junction                   3
# Open Tap                         3
# Changezi Chicken                 2
#                                 ..
# Oasis - Vivanta by Taj           1
# Goosebumps                       1
# Pepper Pot - The Terrace Café    1
# Cake Castle                      1
# Pizzasia                         1
# Name: Restaurant_Name, Length: 1943, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=data['Delivery_Rating'])
plt.xlabel("RATING")
plt.ylabel("NO.OF PEOPLE")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Q3.What type of food is most preffered by the customers?

# %%
A1=data['Category'].value_counts()
print(A1)
# Out:
# North Indian                                                      88
# North Indian, Chinese                                             39
# North Indian, Mughlai                                             37
# Pizza, Fast Food                                                  19
# North Indian, Chinese, Mughlai                                    17
#                                                                   ..
# North Indian, Kebab, Mughlai, Biryani, Beverages                   1
# North Indian, Continental, Italian, Chinese                        1
# North Indian, Continental, Asian, Chinese                          1
# Afghan, Iranian, Awadhi, Beverages                                 1
# Cafe, North Indian, Chinese, Kashmiri, Rolls, Pizza, Beverages     1
# Name: Category, Length: 1355, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.hist(A1, bins=100,width=0.5)
plt.show()

# %% [markdown]
# MOST PREFERRED FOOD IS NORTH INDIAN , AS SHOWN IN THE GRAPH

# %% [markdown]
# Q4.How many people prefer delivery rather than dining ?

# %%
data['Delivery_Rating_Count']
# Out:
# 0       1844
# 1         37
# 2          0
# 3       1238
# 4          0
#         ...
# 1960     545
# 1961       1
# 1962    2977
# 1963     196
# 1964    5196
# Name: Delivery_Rating_Count, Length: 1965, dtype: int64

# %%
data['Dining_Review_Count']
# Out:
# 0       1885
# 1       3748
# 2       1371
# 3       2636
# 4       6487
#         ...
# 1960     183
# 1961     114
# 1962     316
# 1963     120
# 1964     165
# Name: Dining_Review_Count, Length: 1965, dtype: int64

# %%
data.plot(y=["Delivery_Rating_Count","Dining_Review_Count"])
# Out:
# <Axes: >

# %%
print (data["Delivery_Rating_Count"].sum(),"people prefer delivery, whereas",data["Dining_Review_Count"].sum(),"prefer dining",)
# Out:
# 5953067 people prefer delivery, whereas 1418640 prefer dining

# %% [markdown]
# Q5.Which restaurant is the best one having ratings more than 4.5 for dining?

# %%
data['Dining_Rating']>4.5
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1960    False
# 1961    False
# 1962    False
# 1963    False
# 1964    False
# Name: Dining_Rating, Length: 1965, dtype: bool

# %%
data['Dining_Rating'].value_counts(normalize=True)
# Out:
# 4.0    0.230534
# 4.1    0.195420
# 3.9    0.169975
# 4.2    0.152672
# 4.3    0.101272
# 4.4    0.065649
# 4.5    0.040204
# 4.6    0.022392
# 4.7    0.012214
# 4.8    0.005089
# 4.9    0.004580
# Name: Dining_Rating, dtype: float64

# %%
data['Restaurant_Name'].value_counts()
# Out:
# Punjabi Zaika                    4
# Champaran Meat House             3
# Kathi Junction                   3
# Open Tap                         3
# Changezi Chicken                 2
#                                 ..
# Oasis - Vivanta by Taj           1
# Goosebumps                       1
# Pepper Pot - The Terrace Café    1
# Cake Castle                      1
# Pizzasia                         1
# Name: Restaurant_Name, Length: 1943, dtype: int64

# %%
A1=data['Restaurant_Name'][(data['Dining_Rating']>=4.5)]
A2=data[['Restaurant_Name','Dining_Review_Count']][(data['Dining_Rating']>=4.5)].sort_values('Dining_Review_Count')
A2
# Out:
#                           Restaurant_Name  Dining_Review_Count
# 42                     Echoes Living Room                    3
# 165                   Only Bar Restaurant                   91
# 93                                   Rooh                  247
# 152  The Haven International Coffee House                  282
# 158                         Little Saigon                  440
# ..                                    ...                  ...
# 89                   The Drunken Botanist                 6302
# 4                           The Big Chill                 6487
# 20                                 Gulati                 6509
# 51              AB's - Absolute Barbecues                 8002
# 54                        Saravana Bhavan                 8305
#
# [166 rows x 2 columns]

# %%
sns.barplot(x=A1,y='Dining_Review_Count',data=data)
# Out:
# <Axes: xlabel='Restaurant_Name', ylabel='Dining_Review_Count'>

# %% [markdown]
# Q6.Compare different delivery rating counts of different restaurants.
# Also tell that which restaurants has got the highest rating counts.
# Do this by creating a barplot

# %%
data['Restaurant_Name'].value_counts()
# Out:
# Punjabi Zaika                    4
# Champaran Meat House             3
# Kathi Junction                   3
# Open Tap                         3
# Changezi Chicken                 2
#                                 ..
# Oasis - Vivanta by Taj           1
# Goosebumps                       1
# Pepper Pot - The Terrace Café    1
# Cake Castle                      1
# Pizzasia                         1
# Name: Restaurant_Name, Length: 1943, dtype: int64

# %%
data['Delivery_Rating_Count']>4.5
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1960     True
# 1961    False
# 1962     True
# 1963     True
# 1964     True
# Name: Delivery_Rating_Count, Length: 1965, dtype: bool

# %%
plt.figure(figsize=(15,10))
data['Restaurant_Name'].value_counts().plot(kind='bar')
plt.xlabel("Name")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.histplot(x=data['Delivery_Rating_Count'], bins=50)
# Out:
# <Axes: xlabel='Delivery_Rating_Count', ylabel='Count'>
